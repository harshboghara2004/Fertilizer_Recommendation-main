# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Nutrient_recommendation.csv')
df
# Out:
#         Crop  Temperature   Humidity    Rainfall  Label_N  Label_P  Label_K
# 0       rice    20.879744  82.002744  202.935536       90       42       43
# 1       rice    21.770462  80.319644  226.655537       85       58       41
# 2       rice    23.004459  82.320763  263.964248       60       55       44
# 3       rice    26.491096  80.158363  242.864034       74       35       40
# 4       rice    20.130175  81.604873  262.717340       78       42       42
# ...      ...          ...        ...         ...      ...      ...      ...
# 2195  coffee    26.774637  66.413269  177.774507      107       34       32
# 2196  coffee    27.417112  56.636362  127.924610       99       15       27
# 2197  coffee    24.131797  67.225123  173.322839      118       33       30
# 2198  coffee    26.272418  52.127394  127.175293      117       32       34
# 2199  coffee    23.603016  60.396475  140.937041      104       18       30
#
# [2200 rows x 7 columns]

# %%
df.nunique()
# Out:
# Crop             22
# Temperature    2200
# Humidity       2200
# Rainfall       2200
# Label_N         137
# Label_P         117
# Label_K          73
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Crop           0
# Temperature    0
# Humidity       0
# Rainfall       0
# Label_N        0
# Label_P        0
# Label_K        0
# dtype: int64

# %%
df_rice = df[df['Crop']=='rice']
df_rice
# Out:
#     Crop  Temperature   Humidity    Rainfall  Label_N  Label_P  Label_K
# 0   rice    20.879744  82.002744  202.935536       90       42       43
# 1   rice    21.770462  80.319644  226.655537       85       58       41
# 2   rice    23.004459  82.320763  263.964248       60       55       44
# 3   rice    26.491096  80.158363  242.864034       74       35       40
# 4   rice    20.130175  81.604873  262.717340       78       42       42
# ..   ...          ...        ...         ...      ...      ...      ...
# 95  rice    22.683191  83.463583  194.265172       88       46       42
# 96  rice    21.533463  82.140041  295.924880       93       47       37
# 97  rice    21.408658  83.329319  287.576693       60       55       45
# 98  rice    26.543481  84.673536  183.622266       78       35       44
# 99  rice    23.359054  83.595123  188.413665       65       37       40
#
# [100 rows x 7 columns]

# %%
crop_names = df['Crop']
nitrogen = df['Label_N']
phosphorus = df['Label_P']
potassium = df['Label_K']
temperature = df['Temperature']
humidity = df['Humidity']
rainfall = df['Rainfall']

# %%
plt.figure(figsize=(10, 6))
plt.plot(crop_names, nitrogen, marker='o', label='Nitrogen')
plt.plot(crop_names, phosphorus, marker='o', label='Phosphorus')
plt.plot(crop_names, potassium, marker='o', label='Potassium')

plt.xlabel('Crop')
plt.ylabel('Nutrient Requirement')
plt.title('Crop vs. NPK Requirements')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(crop_names, temperature, color='skyblue')
plt.xlabel('Crop')
plt.ylabel('Temperature (°C)')
plt.title('Crop vs. Temperature')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(crop_names, humidity, color='lightgreen')
plt.xlabel('Crop')
plt.ylabel('Humidity')
plt.title('Crop vs. Humidity')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(crop_names, rainfall, color='lightcoral')
plt.xlabel('Crop')
plt.ylabel('Rainfall (mm)')
plt.title('Crop vs. Rainfall')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()
